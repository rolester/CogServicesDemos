# %%
print('a')
# Out:
# a

# %%
subscription_key = open("subkey.key","r").readline()
location = "northeurope"
endpoint = "https://api.cognitive.microsofttranslator.com"

# %%
#Translate Text
import requests, uuid, json

path = '/translate'
constructed_url = endpoint + path

params = {
    'api-version': '3.0',
    'from': 'en',
    'to': ['de', 'it', 'es', 'th'],
    'includeSentenceLength': True
}
constructed_url = endpoint + path

headers = {
    'Ocp-Apim-Subscription-Key': subscription_key,
    'Ocp-Apim-Subscription-Region': location,
    'Content-type': 'application/json',
    'X-ClientTraceId': str(uuid.uuid4())
}

# You can pass more than one object in body.
body = [{
    'text': 'Hello fast car'
}]

request = requests.post(constructed_url, params=params, headers=headers, json=body)
response = request.json()

print(json.dumps(response, sort_keys=True, ensure_ascii=False, indent=4, separators=(',', ': ')))
# Out:
# [
#     {
#         "translations": [
#             {
#                 "sentLen": {
#                     "srcSentLen": [
#                         14
#                     ],
#                     "transSentLen": [
#                         20
#                     ]
#                 },
#                 "text": "Hallo schnelles Auto",
#                 "to": "de"
#             },
#             {
#                 "sentLen": {
#                     "srcSentLen": [
#                         14
#                     ],
#                     "transSentLen": [
#                         16
#                     ]
#                 },
#                 "text": "Ciao auto veloce",
#                 "to": "it"
#             },
#             {
#                 "sentLen": {
#                     "srcSentLen": [
#                         14
#                     ],
#                     "transSentLen": [
#                         17
#                     ]
#                 },
#                 "text": "Hola coche rápido",
#                 "to": "es"
#             },
#             {
#                 "sentLen": {
#                     "srcSentLen": [
#                         14
#                     ],
#                     "transSentLen": [
#                         12
#                     ]
#                 },
#                 "text": "สวัสดีรถเร็ว",
#                 "to": "th"
#             }
#         ]
#     }
# ]

# %%
#Detect Language
import requests, uuid, json

path = '/detect'
constructed_url = endpoint + path

params = {
    'api-version': '3.0'
}
constructed_url = endpoint + path

headers = {
    'Ocp-Apim-Subscription-Key': subscription_key,
    'Ocp-Apim-Subscription-Region': location,
    'Content-type': 'application/json',
    'X-ClientTraceId': str(uuid.uuid4())
}

# You can pass more than one object in body.
body = [{
    'text': 'สวัสดีรถเร็ว'
}]

request = requests.post(constructed_url, params=params, headers=headers, json=body)
response = request.json()

print(json.dumps(response, sort_keys=True, ensure_ascii=False, indent=4, separators=(',', ': ')))

#(Transliteration = to convert text in one language from one script to another script.)
# Out:
# [
#     {
#         "isTranslationSupported": true,
#         "isTransliterationSupported": true,
#         "language": "th",
#         "score": 1.0
#     }
# ]

# %%
#Alternative dictionary translations
import requests, uuid, json

path = '/dictionary/lookup'
constructed_url = endpoint + path

params = {
    'api-version': '3.0',
    'from': 'en',
    'to': 'de'
}
constructed_url = endpoint + path

headers = {
    'Ocp-Apim-Subscription-Key': subscription_key,
    'Ocp-Apim-Subscription-Region': location,
    'Content-type': 'application/json',
    'X-ClientTraceId': str(uuid.uuid4())
}

# You can pass more than one object in body.
body = [{
    'text': 'lady'
}]
request = requests.post(constructed_url, params=params, headers=headers, json=body)
response = request.json()

print(json.dumps(response, sort_keys=True, ensure_ascii=False, indent=4, separators=(',', ': ')))
# Out:
# [
#     {
#         "displaySource": "lady",
#         "normalizedSource": "lady",
#         "translations": [
#             {
#                 "backTranslations": [
#                     {
#                         "displayText": "lady",
#                         "frequencyCount": 18051,
#                         "normalizedText": "lady",
#                         "numExamples": 1
#                     }
#                 ],
#                 "confidence": 0.9392,
#                 "displayTarget": "dame",
#                 "normalizedTarget": "dame",
#                 "posTag": "OTHER",
#                 "prefixWord": ""
#             },
#             {
#                 "backTranslations": [
#                     {
#                         "displayText": "female",
#                         "frequencyCount": 16355,
#                         "normalizedText": "female",
#                         "numExamples": 0
#                     },
#                     {
#                         "displayText": "woman",
#                         "frequencyCount": 4900,
#                         "normalizedText": "woman",
#                         "numExamples": 0
#                     },
#                     {
#                         "displayText": "feminine",
#                         "frequencyCount": 1181,
#                         "normalizedText": "feminine",
#                         "numExamples": 0
#                     },
#                     {
#                         "displayText": "lady",
#                         "frequencyCount": 1169,
#                         "normalizedText": "lady",
#                         "numExamples": 0
#                     }
#                 ],
#                 "confidence": 0.0608,
#                 "displayTarget": "weiblich",
#                 "normalizedTarget": "weiblich",
#                 "posTag": "NOUN",
#                 "prefixWord": ""
#             }
#         ]
#     }
# ]

# %%
#Alternative dictionary translations
import requests, uuid, json

path = '/dictionary/examples'
constructed_url = endpoint + path

params = {
    'api-version': '3.0',
    'from': 'en',
    'to': 'de'
}
constructed_url = endpoint + path

headers = {
    'Ocp-Apim-Subscription-Key': subscription_key,
    'Ocp-Apim-Subscription-Region': location,
    'Content-type': 'application/json',
    'X-ClientTraceId': str(uuid.uuid4())
}

# You can pass more than one object in body.
body = [{
    'text': 'lady',
    'translation': 'dame'
}]
request = requests.post(constructed_url, params=params, headers=headers, json=body)
response = request.json()

print(json.dumps(response, sort_keys=True, ensure_ascii=False, indent=4, separators=(',', ': ')))
# Out:
# [
#     {
#         "examples": [
#             {
#                 "sourcePrefix": "My dear ",
#                 "sourceSuffix": ", you are pleading for yourself.",
#                 "sourceTerm": "lady",
#                 "targetPrefix": "Verehrte ",
#                 "targetSuffix": ", Sie verteidigen sich bloß selbst.",
#                 "targetTerm": "Dame"
#             },
#             {
#                 "sourcePrefix": "An enviable role for this most changeable ",
#                 "sourceSuffix": "!",
#                 "sourceTerm": "lady",
#                 "targetPrefix": "Eine beneidenswerte Rolle für diese absolut wandelbare ",
#                 "targetSuffix": "!",
#                 "targetTerm": "Dame"
#             },
#             {
#                 "sourcePrefix": "The ",
#                 "sourceSuffix": " and gentlemen are in surprising agreement on ...",
#                 "sourceTerm": "lady",
#                 "targetPrefix": "Erstaunlich einig sind sich die ",
#                 "targetSuffix": " und die Herren bei ...",
#                 "targetTerm": "Dame"
#             }
#         ],
#         "normalizedSource": "lady",
#         "normalizedTarget": "dame"
#     }
# ]

# %%
#Profanity Filter
import requests, uuid, json

path = '/translate'
constructed_url = endpoint + path

params = {
    'api-version': '3.0',
    'from': 'en',
    'to': ['de', 'it'],
    'includeSentenceLength': True,
    'profanityAction' : 'Marked',
    'profanityMarker' : 'Tag'
}
constructed_url = endpoint + path

headers = {
    'Ocp-Apim-Subscription-Key': subscription_key,
    'Ocp-Apim-Subscription-Region': location,
    'Content-type': 'application/json',
    'X-ClientTraceId': str(uuid.uuid4())
}

# You can pass more than one object in body.
body = [{
    'text': 'What are you? Some bottom-feeding, scum sucking algae eater?'
}]

request = requests.post(constructed_url, params=params, headers=headers, json=body)
response = request.json()

print(json.dumps(response, sort_keys=True, ensure_ascii=False, indent=4, separators=(',', ': ')))
# Out:
# [
#     {
#         "translations": [
#             {
#                 "sentLen": {
#                     "srcSentLen": [
#                         14,
#                         46
#                     ],
#                     "transSentLen": [
#                         12,
#                         75
#                     ]
#                 },
#                 "text": "Was machst? Einige Bodenfütterung, <profanity>abschaum</profanity> saugen Algenfresser?",
#                 "to": "de"
#             },
#             {
#                 "sentLen": {
#                     "srcSentLen": [
#                         14,
#                         46
#                     ],
#                     "transSentLen": [
#                         11,
#                         53
#                     ]
#                 },
#                 "text": "Cosa stai? Un mangiatore di alghe che succhia il fondo e feccia?",
#                 "to": "it"
#             }
#         ]
#     }
# ]
